# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

# if not os.environ.get("FIREWORKS_API_KEY"):
#     os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

if not os.environ.get("GROQ_API_KEY"):
    os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
# from langchain_fireworks import ChatFireworks

from langchain_openai import ChatOpenAI

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "openai/gpt-oss-20b"

# llm = ChatFireworks(model=model_endpoint)

llm = ChatOpenAI(
    model=model_endpoint,
    openai_api_key=os.environ["GROQ_API_KEY"],
    openai_api_base="https://api.groq.com/openai/v1",
)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# The tongue‑twister doesn’t actually give a number – it simply says
#
# > “A wood‑chuck would chuck as much wood as a wood‑chuck could chuck if a wood‑chuck could chuck wood.”
#
# In other words, *whatever a woodchuck can manage*.
#
# For a bit of fun, a popular “scientific” estimate (from a 1988 US Forest Service study by wildlife biologist Richard Thomas) puts the figure at roughly **700 pounds** (about 320 kg) of wood per day, assuming the animal could actually move that much material. It’s a playful number, not a precise measurement, but it’s what most people quote when they want a concrete answer to the question.

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 21: **Classic tongue‑twister answer**
#
# > “A woodchuck would chuc...
# Response 9: A classic tongue‑twister! In the traditional rhyme, the answ...
# Response 3: A woodchuck would chuck as much wood as a woodchuck could—ab...
# Response 23: As the tongue‑twister goes, a woodchuck would chuck “as much...
# Response 1: **Answer to “How much wood could a wood‑chuck chuck if a woo...
# Response 5: If a wood‑chuck could chuck wood, it would probably shove ar...
# Response 6: Ah, the classic tongue‑twister! While no woodchuck actually ...
# Response 11: The classic tongue‑twister goes:
#
# **“How much wood would a...
# Response 22: It’s a classic riddle rather than a science question, but if...
# Response 4: A woodchuck would chuck as much wood as a woodchuck would ch...
# Response 8: A woodchuck would chuck “as much wood as a woodchuck could c...
# Response 16: Ah, the classic tongue‑twister that never fails to stump and...
# Response 20: A woodchuck could chuck as much wood as the wind would push ...
# Response 2: **Answer (the classic tongue‑twister version)**
# > *“A wood...
# Response 12: The classic tongue‑twister itself is the answer:
#
# > “A wood‑...
# Response 18: **Answer to the classic tongue‑twister**
#
# > “How much wood c...
# Response 14: **Answer (tongue‑twister style)**
# *If a woodchuck could ch...
# Response 17: A woodchuck would chuck as much wood as a woodchuck could ch...
# Response 13: If a woodchuck could chuck wood, it would chuck **as much wo...
# Response 7: The classic tongue‑twister doesn’t actually give us a concre...
# Response 10: A classic tongue‑twister answer is simply:
#
# > **A woodchuck ...
# Response 15: A woodchuck would chuck 700 pounds of wood, assuming it coul...
# Response 19: ### The “wood‑chuck” mystery
#
# The classic question *“How muc...
# Response 24: It’s a classic tongue‑twister, so the answer is as playful a...
